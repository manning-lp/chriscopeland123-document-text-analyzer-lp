# %%
# Sample document structure
sample_documents = {
    "doc_name": "Document content here...",
    "another_doc": "More content..."
}

# Manual ground truth structure
ground_truth = {
    "doc_name": {
        "entities": {"People": ["Name1"], "Organizations": ["Org1"]},
        "classification": {"type": "business", "formality": "formal"}
    }
}

# Testing loop pattern
for doc_name, doc_text in sample_documents.items():
    entities = analyzer.extract_entities(doc_text)
    summary = analyzer.generate_summary(doc_text)
    classification = analyzer.classify_document(doc_text)

# Accuracy calculation pattern
def calculate_accuracy(ai_results, ground_truth):
    correct = 0
    total = 0
    # Compare and count matches
    return (correct / total) * 100 if total > 0 else 0

# Edge case testing
try:
    result = analyzer.extract_entities(edge_case_text)
    print(f"Success: {result}")
except Exception as e:
    print(f"Error handled: {e}")
